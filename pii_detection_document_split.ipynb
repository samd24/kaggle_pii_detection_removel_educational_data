# %%
import pandas as pd


json_file_path = 'data/pii-detection-removal-from-educational-data/train.json'
train_df = pd.read_json(json_file_path)

train_df.head()
# Out:
#    document                                          full_text  \
# 0         7  Design Thinking for innovation reflexion-Avril...
# 1        10  Diego Estrada\n\nDesign Thinking Assignment\n\...
# 2        16  Reporting process\n\nby Gilberto Gamboa\n\nCha...
# 3        20  Design Thinking for Innovation\n\nSindy Samaca...
# 4        56  Assignment:  Visualization Reflection  Submitt...
#
#                                               tokens  \
# 0  [Design, Thinking, for, innovation, reflexion,...
# 1  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 2  [Reporting, process, \n\n, by, Gilberto, Gambo...
# 3  [Design, Thinking, for, Innovation, \n\n, Sind...
# 4  [Assignment, :,   , Visualization,  , Reflecti...
#
#                                  trailing_whitespace  \
# 0  [True, True, True, True, False, False, True, F...
# 1  [True, False, False, True, True, False, False,...
# 2  [True, False, False, True, True, False, False,...
# 3  [True, True, True, False, False, True, False, ...
# 4  [False, False, False, False, False, False, Fal...
#
#                                               labels
# 0  [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...
# 1  [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 2  [O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT, O...
# 3  [O, O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT...
# 4  [O, O, O, O, O, O, O, O, O, O, O, O, B-NAME_ST...

# %%
# drop irrelevant cols
cols_to_drop = ['full_text', 'trailing_whitespace']
train_df = train_df.drop(columns=cols_to_drop, axis=1)
train_df
# Out:
#       document                                             tokens  \
# 0            7  [Design, Thinking, for, innovation, reflexion,...
# 1           10  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 2           16  [Reporting, process, \n\n, by, Gilberto, Gambo...
# 3           20  [Design, Thinking, for, Innovation, \n\n, Sind...
# 4           56  [Assignment, :,   , Visualization,  , Reflecti...
# ...        ...                                                ...
# 6802     22678  [EXAMPLE, –, JOURNEY, MAP, \n\n, THE, CHALLENG...
# 6803     22679  [Why, Mind, Mapping, ?, \n\n, Mind, maps, are,...
# 6804     22681  [Challenge, \n\n, So, ,, a, few, months, back,...
# 6805     22684  [Brainstorming, \n\n, Challenge, &, Selection,...
# 6806     22687  [Mind, Mapping, \n\n, Challenge, \n\n, My, con...
#
#                                                  labels
# 0     [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...
# 1     [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 2     [O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT, O...
# 3     [O, O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT...
# 4     [O, O, O, O, O, O, O, O, O, O, O, O, B-NAME_ST...
# ...                                                 ...
# 6802  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 6803  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 6804  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 6805  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 6806  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
# [6807 rows x 3 columns]

# %%
# create len tokens column
train_df['number of tokens'] = train_df.tokens.apply(len)
train_df
# Out:
#       document                                             tokens  \
# 0            7  [Design, Thinking, for, innovation, reflexion,...
# 1           10  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 2           16  [Reporting, process, \n\n, by, Gilberto, Gambo...
# 3           20  [Design, Thinking, for, Innovation, \n\n, Sind...
# 4           56  [Assignment, :,   , Visualization,  , Reflecti...
# ...        ...                                                ...
# 6802     22678  [EXAMPLE, –, JOURNEY, MAP, \n\n, THE, CHALLENG...
# 6803     22679  [Why, Mind, Mapping, ?, \n\n, Mind, maps, are,...
# 6804     22681  [Challenge, \n\n, So, ,, a, few, months, back,...
# 6805     22684  [Brainstorming, \n\n, Challenge, &, Selection,...
# 6806     22687  [Mind, Mapping, \n\n, Challenge, \n\n, My, con...
#
#                                                  labels  number of tokens
# 0     [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...               753
# 1     [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...               563
# 2     [O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT, O...               729
# 3     [O, O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT...              1071
# 4     [O, O, O, O, O, O, O, O, O, O, O, O, B-NAME_ST...              1927
# ...                                                 ...               ...
# 6802  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               601
# 6803  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               433
# 6804  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               633
# 6805  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               679
# 6806  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               820
#
# [6807 rows x 4 columns]

# %%
train_df.describe()
# Out:
#            document  number of tokens
# count   6807.000000       6807.000000
# mean   14739.782283        733.441017
# std     4920.715769        319.244697
# min        7.000000         69.000000
# 25%    11061.500000        520.000000
# 50%    14818.000000        693.000000
# 75%    18974.000000        897.000000
# max    22687.000000       3298.000000

# %%
train_df.iloc[0]
# Out:
# document                                                            7
# tokens              [Design, Thinking, for, innovation, reflexion,...
# labels              [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...
# number of tokens                                                  753
# Name: 0, dtype: object

# %%
token_list = train_df.tokens[0]
labels_list = train_df.labels[0]
row = train_df.iloc[0]

def spilt_long_document(row, max_len=400):
    doc_number = row.document
    doc_tokens = row.tokens
    doc_labels = row.labels
    new_tokens_labels = []
    i = 0
    while len(doc_tokens) > max_len:
        # check the last token is not a NER tag
        if doc_labels[max_len] != 'O':
            # print(doc_labels[max_len], doc_labels[max_len+1])
            new_max_len = max_len
            # itterate through the token list until there is an 'O' and make the split there
            while doc_labels[new_max_len] != 'O':
                new_max_len += 1
            new_tokens = doc_tokens[:new_max_len]
            new_labels = doc_labels[:new_max_len]
            new_tokens_labels.append({'doc_number': doc_number, 'split': i, 'tokens': new_tokens, 'labels':new_labels})
            # update the tokens and labels lists
            doc_tokens = doc_tokens[new_max_len:]
            doc_labels = doc_labels[new_max_len:]
            i += 1

        else:  
            new_tokens = doc_tokens[:max_len]
            new_labels = doc_labels[:max_len]
            new_tokens_labels.append({'doc_number': doc_number, 'split': i, 'tokens': new_tokens, 'labels':new_labels})
            # update the tokens and labels lists
            doc_tokens = doc_tokens[max_len:]
            doc_labels = doc_labels[max_len:]
            i += 1
    # write the last part of the list to the new lists
    new_tokens_labels.append({'doc_number': doc_number, 'split': i, 'tokens': doc_tokens, 'labels':doc_labels})

    # return a dataframe with the new rows (spit cols and labels)
    return pd.DataFrame(new_tokens_labels)


row0new = spilt_long_document(row)
len(row0new)
# Out:
# 2

# %%
# initialize new pandas dataframe
new_train_df = pd.DataFrame()

# itterate through train_df, split the long texts and insert the new row into the new dataframe
for index, row in train_df.iterrows():
    # split documents
    new_rows = spilt_long_document(row)
    # append the new rows to the new_train_df
    for i, r in new_rows.iterrows():
        new_train_df = pd.concat([new_train_df, pd.DataFrame([new_rows.iloc[i]])], ignore_index=True)

# %%
new_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15889 entries, 0 to 15888
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   doc_number  15889 non-null  int64
#  1   split       15889 non-null  int64
#  2   tokens      15889 non-null  object
#  3   labels      15889 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 496.7+ KB

# %%
len(new_train_df['tokens'][0])
# Out:
# 400

# %%
new_train_df.head()
# Out:
#    doc_number  split                                             tokens  \
# 0           7      0  [Design, Thinking, for, innovation, reflexion,...
# 1           7      1  [of, questions, ,, we, can, use, :, who, ,, wh...
# 2          10      0  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 3          10      1  [which, eases, the,  , work, of, the, team, .,...
# 4          16      0  [Reporting, process, \n\n, by, Gilberto, Gambo...
#
#                                               labels
# 0  [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...
# 1  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2  [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...
# 3  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4  [O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT, O...

# %%
type(new_train_df['labels'][0])
# Out:
# list

# %%
# create len tokens column
new_train_df['number of tokens'] = new_train_df.tokens.apply(len)
new_train_df
# Out:
#        doc_number  split                                             tokens  \
# 0               7      0  [Design, Thinking, for, innovation, reflexion,...
# 1               7      1  [of, questions, ,, we, can, use, :, who, ,, wh...
# 2              10      0  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 3              10      1  [which, eases, the,  , work, of, the, team, .,...
# 4              16      0  [Reporting, process, \n\n, by, Gilberto, Gambo...
# ...           ...    ...                                                ...
# 15884       22684      0  [Brainstorming, \n\n, Challenge, &, Selection,...
# 15885       22684      1  [on, which, ones, were, the, best, ., We, came...
# 15886       22687      0  [Mind, Mapping, \n\n, Challenge, \n\n, My, con...
# 15887       22687      1  [had, to, consider, for, their, portions, were...
# 15888       22687      2  [stating, the, factors, determining,  , wellbe...
#
#                                                   labels  number of tokens
# 0      [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...               400
# 1      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               353
# 2      [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...               400
# 3      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               163
# 4      [O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT, O...               400
# ...                                                  ...               ...
# 15884  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               400
# 15885  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               279
# 15886  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               400
# 15887  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               400
# 15888  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...                20
#
# [15889 rows x 5 columns]

# %%
new_train_df.describe()
# Out:
#          doc_number         split  number of tokens
# count  15889.000000  15889.000000      15889.000000
# mean   14583.960539      0.822896        314.213166
# std     4967.956870      0.897772        124.220914
# min        7.000000      0.000000          1.000000
# 25%    10946.000000      0.000000        230.000000
# 50%    14593.000000      1.000000        400.000000
# 75%    18835.000000      1.000000        400.000000
# max    22687.000000      8.000000        402.000000

# %%
import matplotlib.pyplot as plt

counts = new_train_df['number of tokens']
# Plotting the histogram
plt.boxplot(counts, showfliers=True)
plt.xlabel('Tokens')
plt.ylabel('Token Counts')
plt.title('Box Plot of Token Counts')
plt.show()

# %%
# how many texts unded 5?
less_than_5 = new_train_df[new_train_df['number of tokens'] < 5]
less_than_5
# Out:
#        doc_number  split                              tokens  \
# 199          2651      3                    [de, Bono, \n\n]
# 202          2660      2                           [., \n\n]
# 298          3427      5                           [., \n\n]
# 379          3915      3                              [\n\n]
# 436          4227      2  [confidentiality, agreement, \n\n]
# 450          4295      1                              [\n\n]
# 490          4433      2                           [., \n\n]
# 603          4956      2                              [\n\n]
# 1095         7084      1                  [service, ., \n\n]
# 1155         7411      1         [\n\n, Jose, Camacho, \n\n]
# 1408         8612      1     [respective, analysis, ., \n\n]
# 2009         9241      2                              [\n\n]
# 2753         9889      1                           [., \n\n]
# 2865        10000      2            [to, greatness, ., \n\n]
# 3170        10245      2                              [\n\n]
# 3454        10485      2                              [\n\n]
# 3722        10721      2           [was, initiated, ., \n\n]
# 4094        11050      1        [customer, experience, \n\n]
# 4145        11100      1                           [., \n\n]
# 4565        11445      2                              [\n\n]
# 4851        11680      2         [targeted, audiences, \n\n]
# 4909        11738      1           [effective,  , way, \n\n]
# 4991        11813      2                           [., \n\n]
# 5045        11855      1                    [needs, ., \n\n]
# 5117        11922      1              [effectively, ., \n\n]
# 5479        12222      3                           [., \n\n]
# 6004        12687      1                           [., \n\n]
# 6806        13368      2                     [work, ., \n\n]
# 6869        13435      2                              [\n\n]
# 6978        13553      1                           [., \n\n]
# 7117        13698      2                           [., \n\n]
# 7323        13937      1                   [method, ., \n\n]
# 7367        13974      1                              [\n\n]
# 7387        14001      1           [peer, learning, ., \n\n]
# 7466        14075      1                [community, ., \n\n]
# 7760        14416      3                           [., \n\n]
# 8028        14678      2               [the, users, ., \n\n]
# 8107        14775      1                              [\n\n]
# 8467        15120      4              [the, future, !, \n\n]
# 8511        15178      1                      [ground, \n\n]
# 8830        15538      1                              [\n\n]
# 9067        15794      1                      [ago, ., \n\n]
# 9158        15883      2                    [sense, ., \n\n]
# 9842        16607      2                           [., \n\n]
# 10049       16869      2              [would, work, ., \n\n]
# 11321       18187      2                           [., \n\n]
# 11418       18292      2                              [\n\n]
# 12024       18961      1                              [\n\n]
# 13143       20022      2            [full, rollout, ., \n\n]
# 13209       20078      2                           [., \n\n]
# 13304       20173      2                              [\n\n]
# 13418       20327      1            [other, creatyres, \n\n]
# 13618       20538      2              [earn, money, ., \n\n]
# 13691       20610      2                              [\n\n]
# 13856       20789      2          [and, experience, ., \n\n]
# 14155       21070      2              [a, criteria, ., \n\n]
# 14270       21147      1                           [., \n\n]
# 14382       21229      2            [other, better, ., \n\n]
# 14871       21686      2                              [\n\n]
# 15371       22193      2             [consequences, ., \n\n]
#
#                                        labels  number of tokens
# 199                                 [O, O, O]                 3
# 202                                    [O, O]                 2
# 298                                    [O, O]                 2
# 379                                       [O]                 1
# 436                                 [O, O, O]                 3
# 450                                       [O]                 1
# 490                                    [O, O]                 2
# 603                                       [O]                 1
# 1095                                [O, O, O]                 3
# 1155   [O, B-NAME_STUDENT, I-NAME_STUDENT, O]                 4
# 1408                             [O, O, O, O]                 4
# 2009                                      [O]                 1
# 2753                                   [O, O]                 2
# 2865                             [O, O, O, O]                 4
# 3170                                      [O]                 1
# 3454                                      [O]                 1
# 3722                             [O, O, O, O]                 4
# 4094                                [O, O, O]                 3
# 4145                                   [O, O]                 2
# 4565                                      [O]                 1
# 4851                                [O, O, O]                 3
# 4909                             [O, O, O, O]                 4
# 4991                                   [O, O]                 2
# 5045                                [O, O, O]                 3
# 5117                                [O, O, O]                 3
# 5479                                   [O, O]                 2
# 6004                                   [O, O]                 2
# 6806                                [O, O, O]                 3
# 6869                                      [O]                 1
# 6978                                   [O, O]                 2
# 7117                                   [O, O]                 2
# 7323                                [O, O, O]                 3
# 7367                                      [O]                 1
# 7387                             [O, O, O, O]                 4
# 7466                                [O, O, O]                 3
# 7760                                   [O, O]                 2
# 8028                             [O, O, O, O]                 4
# 8107                                      [O]                 1
# 8467                             [O, O, O, O]                 4
# 8511                                   [O, O]                 2
# 8830                                      [O]                 1
# 9067                                [O, O, O]                 3
# 9158                                [O, O, O]                 3
# 9842                                   [O, O]                 2
# 10049                            [O, O, O, O]                 4
# 11321                                  [O, O]                 2
# 11418                                     [O]                 1
# 12024                                     [O]                 1
# 13143                            [O, O, O, O]                 4
# 13209                                  [O, O]                 2
# 13304                                     [O]                 1
# 13418                               [O, O, O]                 3
# 13618                            [O, O, O, O]                 4
# 13691                                     [O]                 1
# 13856                            [O, O, O, O]                 4
# 14155                            [O, O, O, O]                 4
# 14270                                  [O, O]                 2
# 14382                            [O, O, O, O]                 4
# 14871                                     [O]                 1
# 15371                               [O, O, O]                 3

# %%
# save new dataset as csv
new_train_df.to_csv('data/split_tokens_short/train_data_short.csv', index=False)
# save as json
new_train_df.to_json('data/split_tokens_short/train_data_short.json', orient='records', lines=True)

# %%
df_exploded = new_train_df.explode('labels')
# Count the occurrences of each unique string
label_counts = df_exploded['labels'].value_counts()

# Display the counts
print(label_counts)
# Out:
# labels
# O                   4989794
# B-NAME_STUDENT         1365
# I-NAME_STUDENT         1096
# B-URL_PERSONAL          110
# B-ID_NUM                 78
# B-EMAIL                  39
# I-STREET_ADDRESS         20
# I-PHONE_NUM              15
# B-USERNAME                6
# B-PHONE_NUM               6
# B-STREET_ADDRESS          2
# I-URL_PERSONAL            1
# I-ID_NUM                  1
# Name: count, dtype: int64

# %%
label_list = list(label_counts.index)
label_list
# Out:
# ['O',
#  'B-NAME_STUDENT',
#  'I-NAME_STUDENT',
#  'B-URL_PERSONAL',
#  'B-ID_NUM',
#  'B-EMAIL',
#  'I-STREET_ADDRESS',
#  'I-PHONE_NUM',
#  'B-USERNAME',
#  'B-PHONE_NUM',
#  'B-STREET_ADDRESS',
#  'I-URL_PERSONAL',
#  'I-ID_NUM']

# %%
# not labeled data
labeled_rows = 0
for ls in new_train_df['labels']:
    for i in ls:
        if i.startswith('B'):
            labeled_rows += 1
            break

labeled_rows
# Out:
# 1144

# %%
# select only the rows with labeled data
# get the idexes of the rows with labeled data
labeled_rows_idx = []
for idx, ls in enumerate(new_train_df['labels']):
    for i in ls:
        if i.startswith('B'):
            labeled_rows_idx.append(idx)
            break
            

len(labeled_rows_idx)
# Out:
# 1144

# %%
labeled_rows_new_train_df= new_train_df.iloc[labeled_rows_idx]
labeled_rows_new_train_df
# Out:
#        doc_number  split                                             tokens  \
# 0               7      0  [Design, Thinking, for, innovation, reflexion,...
# 1               7      1  [of, questions, ,, we, can, use, :, who, ,, wh...
# 2              10      0  [Diego, Estrada, \n\n, Design, Thinking, Assig...
# 3              10      1  [which, eases, the,  , work, of, the, team, .,...
# 4              16      0  [Reporting, process, \n\n, by, Gilberto, Gambo...
# ...           ...    ...                                                ...
# 7832        14484      0  [REFLECTION, :, MIND, MAPPING, \n\n, Challenge...
# 8983        15717      0  [Visualization, \n\n, Visualization, refers, t...
# 8985        15717      2  [stages, of, design, thinking, ., It, is, a, c...
# 12347       19280      0  [Learning, Launch, based, on, Design, Thinking...
# 14067       20984      0  [Design, Thinking, –, Visualization, Tool,    ...
#
#                                                   labels  number of tokens
# 0      [O, O, O, O, O, O, O, O, O, B-NAME_STUDENT, I-...               400
# 1      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               353
# 2      [B-NAME_STUDENT, I-NAME_STUDENT, O, O, O, O, O...               400
# 3      [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               163
# 4      [O, O, O, O, B-NAME_STUDENT, I-NAME_STUDENT, O...               400
# ...                                                  ...               ...
# 7832   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               400
# 8983   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               400
# 8985   [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               400
# 12347  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...               400
# 14067  [O, O, O, O, O, O, B-ID_NUM, O, O, O, O, O, O,...               400
#
# [1144 rows x 5 columns]

# %%
len(labeled_rows_new_train_df['tokens'][0])
# Out:
# 400

# %%
labeled_rows_new_train_df.describe()
# Out:
#          doc_number        split  number of tokens
# count   1144.000000  1144.000000       1144.000000
# mean    7659.880245     0.438811        364.292832
# std     3583.338706     0.834365         84.037950
# min        7.000000     0.000000          4.000000
# 25%     4932.500000     0.000000        400.000000
# 50%     7766.500000     0.000000        400.000000
# 75%    10674.500000     1.000000        400.000000
# max    20984.000000     8.000000        402.000000

# %%
import matplotlib.pyplot as plt

counts = labeled_rows_new_train_df['number of tokens']
# Plotting the histogram
plt.boxplot(counts, showfliers=True)
plt.xlabel('Tokens')
plt.ylabel('Token Counts')
plt.title('Box Plot of Token Counts')
plt.show()

# %%
df_exploded = labeled_rows_new_train_df.explode('labels')
# Count the occurrences of each unique string
label_counts = df_exploded['labels'].value_counts()

# Display the counts
print(label_counts)
# Out:
# labels
# O                   414012
# B-NAME_STUDENT        1365
# I-NAME_STUDENT        1096
# B-URL_PERSONAL         110
# B-ID_NUM                78
# B-EMAIL                 39
# I-STREET_ADDRESS        20
# I-PHONE_NUM             15
# B-USERNAME               6
# B-PHONE_NUM              6
# B-STREET_ADDRESS         2
# I-URL_PERSONAL           1
# I-ID_NUM                 1
# Name: count, dtype: int64
